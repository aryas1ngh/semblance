# %% [markdown]
# # Semblance — train on Kaggle GPU
#
# Full triplet-loss training. All logic lives in `src/`; this notebook only wires
# up paths and calls `train`.
#
# **Setup:** turn on GPU (Settings -> Accelerator -> GPU), and *Add Input* ->
# search "Stanford Online Products" -> attach the dataset.

# %%
# !git clone -q https://github.com/aryas1ngh/semblance.git 2>/dev/null || (cd semblance && git pull -q)
# !pip install -q albumentations pytorch-metric-learning
import sys
sys.path.insert(0, "/kaggle/working/semblance")
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.8/127.8 kB 3.3 MB/s eta 0:00:00

# %%
import glob
from pathlib import Path

# Find the attached SOP dataset regardless of its exact input slug.
hits = glob.glob("/kaggle/input/**/Ebay_train.txt", recursive=True)
assert hits, "Attach the Stanford Online Products dataset via 'Add Input'."
ROOT = Path(hits[0]).parent
print("data root:", ROOT)
# Out:
# data root: /kaggle/input/datasets/supercoolpotato/stanford-online-products/Stanford_Online_Products

# %%
from src.train.trainer import TrainConfig, train

cfg = TrainConfig(
    root=ROOT,
    embedding_dim=512,
    epochs=10,
    lr=1e-4,
    p=16,
    k=4,
    margin=0.2,
    num_workers=2,
    device="auto",
    out_dir=Path("/kaggle/working/out"),
)
train(cfg)
# Out:
# device=cuda | embedding_dim=512 | P=16 K=4
# train: 59,551 imgs / 930 batches | eval: 1,001 imgs
# Downloading: "https://download.pytorch.org/models/resnet50-11ad3fa6.pth" to /root/.cache/torch/hub/checkpoints/resnet50-11ad3fa6.pth
# 100%|██████████| 97.8M/97.8M [00:00<00:00, 136MB/s]
# epoch 1/10:   0%|          | 0/930 [00:00<?, ?it/s]
# epoch   1 | loss 0.0804 | R@1  85.3 | R@10  95.9
# epoch 2/10:   0%|          | 0/930 [00:00<?, ?it/s]
# epoch   2 | loss 0.0781 | R@1  87.7 | R@10  96.0
# epoch 3/10:   0%|          | 0/930 [00:00<?, ?it/s]
# epoch   3 | loss 0.0760 | R@1  87.0 | R@10  96.1
# epoch 4/10:   0%|          | 0/930 [00:00<?, ?it/s]
# epoch   4 | loss 0.0746 | R@1  86.2 | R@10  96.4
# epoch 5/10:   0%|          | 0/930 [00:00<?, ?it/s]
# epoch   5 | loss 0.0732 | R@1  90.0 | R@10  97.0
# epoch 6/10:   0%|          | 0/930 [00:00<?, ?it/s]
# epoch   6 | loss 0.0726 | R@1  89.4 | R@10  97.3
# epoch 7/10:   0%|          | 0/930 [00:00<?, ?it/s]
# epoch   7 | loss 0.0715 | R@1  89.0 | R@10  97.9
# epoch 8/10:   0%|          | 0/930 [00:00<?, ?it/s]
# epoch   8 | loss 0.0711 | R@1  88.9 | R@10  97.8
# epoch 9/10:   0%|          | 0/930 [00:00<?, ?it/s]
# epoch   9 | loss 0.0701 | R@1  89.6 | R@10  97.6
# epoch 10/10:   0%|          | 0/930 [00:00<?, ?it/s]
# epoch  10 | loss 0.0691 | R@1  88.7 | R@10  98.0
# best Recall@1: 90.0% -> /kaggle/working/out/best.pt
# {'best_recall@1': 0.9000998735427856}
